# %%
import matplotlib.pyplot as plt
import numpy as np
from trying import Environment
from matplotlib import rc
rc('animation', html='html5')

env = Environment()
env.place_agents()
env.visualize()

# %%
env.playRound()
env.visualize()

# %%
#anim = env.animate()

# %%
#anim

# %%
env = Environment(migrate = True)
env.place_agents()

for i in range(100):
    env.playRound()
env.visualize()
plt.savefig('E')

anim = env.animate(frames=50, interval=200)

# %%
anim
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
env = Environment(migrate=True)
env.place_agents()
for i in range(200):
    env.playRound()
env.visualize()
plt.savefig('E')

# %%
anim
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
env = SocialNetworkEnv(migrate=True)
env.place_agents()
env.visualize()

anim = env.animate(frames=50, interval=200)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-b98ef2aed09f> in <module>()
# ----> 1 env = SocialNetworkEnv(migrate=True)
#       2 env.place_agents()
#       3 env.visualize()
#       4
#       5 anim = env.animate(frames=50, interval=200)
#
# NameError: name 'SocialNetworkEnv' is not defined

# %%
anim
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5cb4583849aa> in <module>()
# ----> 1 anim
#
# NameError: name 'anim' is not defined

# %%
i=0
while i < 200:
    i += 1
    env.playRound()
env.visualize()
plt.savefig('migrate_100')
