# %%
import matplotlib.pyplot as plt
import numpy as np
from environments import Environment, SocialNetworkEnv
from matplotlib import rc
rc('animation', html='html5')

env = Environment()
env.place_agents()
env.visualize()

# %%
env.playRound()
env.visualize()

# %%
#anim = env.animate()

# %%
#anim

# %%
env = Environment(migrate=True)
env.place_agents()
env.visualize()
anim = env.animate()

# %%
#anim

# %%
env = SocialNetworkEnv(migrate=True)
env.place_agents()
env.visualize()
env.playRound()
anim = env.animate(frames=50, interval=200)

# %%
anim
# Out:
# <video width="600.0" height="400.0" controls autoplay loop>
#   <source type="video/mp4" src="...
